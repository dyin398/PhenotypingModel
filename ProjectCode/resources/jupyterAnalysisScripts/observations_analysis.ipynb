# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime

# %%
observations = pd.read_csv("../inputData/observations.csv")
observations.head(10)
# Out:
#                    DATE                               PATIENT  \
# 0  2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 1  2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 2  2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 3  2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 4  2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 5  2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 6  2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 7  2020-03-05T05:36:30Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 8  2020-03-05T05:36:30Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 9  2020-03-05T06:54:38Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
#
#                               ENCOUNTER     CODE  \
# 0  0d3d5e03-fcba-20fe-ee53-298bbe0e230b   8310-5
# 1  0d3d5e03-fcba-20fe-ee53-298bbe0e230b   9279-1
# 2  0d3d5e03-fcba-20fe-ee53-298bbe0e230b   8867-4
# 3  0d3d5e03-fcba-20fe-ee53-298bbe0e230b   2708-6
# ...

# %%
n = len(pd.unique(observations['PATIENT']))
n
# Out:
# 1046

# %%
observations.isnull().sum()
# Out:
# DATE               0
# PATIENT            0
# ENCOUNTER      29862
# CODE               0
# DESCRIPTION        0
# VALUE              0
# UNITS           4510
# TYPE               0
# dtype: int64

# %%
observations['CODE'].value_counts().head(10)
# Out:
# QALY       9954
# DALY       9954
# QOLS       9954
# 2708-6     3187
# 8310-5     2679
# 8462-4     2461
# 8480-6     2461
# 9279-1     2461
# 29463-7    2461
# 8867-4     2461
# Name: CODE, dtype: int64

# %%
keepCodes = ['8310-5', '9279-1', '8867-4', '2708-6', '8462-4', '8480-6', '29463-7']
clean = observations.loc[observations['CODE'].isin(keepCodes)]
clean
# Out:
#                         DATE                               PATIENT  \
# 0       2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 1       2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 2       2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 3       2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# 4       2020-03-05T05:21:41Z  92a8c64e-8cd4-fe5d-ba9a-7da402646cf0
# ...                      ...                                   ...
# 117404  2020-03-11T14:21:13Z  a6f234b3-34b4-1acb-7560-34005d1519d0
# 117405  2020-03-11T14:21:13Z  a6f234b3-34b4-1acb-7560-34005d1519d0
# 117406  2020-03-11T14:21:13Z  a6f234b3-34b4-1acb-7560-34005d1519d0
# 117407  2020-03-11T14:21:13Z  a6f234b3-34b4-1acb-7560-34005d1519d0
# 117408  2020-03-11T14:21:13Z  a6f234b3-34b4-1acb-7560-34005d1519d0
#
#                                    ENCOUNTER     CODE  \
# 0       0d3d5e03-fcba-20fe-ee53-298bbe0e230b   8310-5
# ...

# %%
clean = clean.drop(['DATE', 'ENCOUNTER'], axis=1)
clean
# Out:
#                                      PATIENT     CODE  \
# 0       92a8c64e-8cd4-fe5d-ba9a-7da402646cf0   8310-5
# 1       92a8c64e-8cd4-fe5d-ba9a-7da402646cf0   9279-1
# 2       92a8c64e-8cd4-fe5d-ba9a-7da402646cf0   8867-4
# 3       92a8c64e-8cd4-fe5d-ba9a-7da402646cf0   2708-6
# 4       92a8c64e-8cd4-fe5d-ba9a-7da402646cf0   8462-4
# ...                                      ...      ...
# 117404  a6f234b3-34b4-1acb-7560-34005d1519d0   8867-4
# 117405  a6f234b3-34b4-1acb-7560-34005d1519d0   2708-6
# 117406  a6f234b3-34b4-1acb-7560-34005d1519d0   8462-4
# 117407  a6f234b3-34b4-1acb-7560-34005d1519d0   8480-6
# 117408  a6f234b3-34b4-1acb-7560-34005d1519d0  29463-7
#
#                                 DESCRIPTION  VALUE   UNITS     TYPE
# 0                          Body temperature   41.5     Cel  numeric
# 1                          Respiratory rate   27.3    /min  numeric
# 2                                Heart rate  123.8    /min  numeric
# ...

# %%
len(pd.unique(clean['TYPE']))
len(pd.unique(clean['UNITS']))
# Out:
# 5
